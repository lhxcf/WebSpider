# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm

# %% [markdown]
# ## 对matplotlib进行设置

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号

# %% [markdown]
# ## 绘制柱状图

# %%
plt.figure(figsize=(10, 6))  # 设置画布大小
df = pd.read_excel('D:\MyPython\AnalysisAndShow\EmotionAnalysis\情感词汇本体.xlsx')
data = df['词语'].value_counts()

x = data.index[:30]
y = data.values[:30]

plt.title('词汇统计', fontsize=40)   # 设置标题/字体大小
plt.xlabel('词语名称', fontsize=20)     # 设置x轴名称
plt.ylabel('出现次数', fontsize=20)     # 设置y轴名称
plt.tick_params(labelsize=14)  # 设置x，y轴字体大小
plt.xticks(rotation=90)     # x文字轴转90度

for a, b in zip(x, y):
    plt.text(a, b+0.01, b, ha='center', va='bottom', fontsize=7)     # 设置柱状图上方显示具体值,ha:设置水平对齐，va:设置垂直对齐

plt.bar(x, y, color='g')
plt.show()

# %% [markdown]
# ## 乳腺癌肿瘤半径与平滑度的关系分析图

# %%
# 对matplotlib进行设置
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号

df = pd.read_excel('乳腺癌诊断数据集.xlsx')
df = df.sort_values(by='半径')
x = df['半径']
y = df['平滑度']
plt.plot(x, y, color='k')
plt.title('肿瘤半径与平滑度关系', fontsize=30)
plt.xlabel('半径', fontsize=20)
plt.ylabel('平滑度', fontsize=20)
plt.savefig('./img/乳腺癌肿瘤半径与平滑度的关系分析图.png', transparent=False)
plt.show()

# %% [markdown]
# ## 肿瘤半径频率分布图

# %%
df = pd.read_excel('乳腺癌诊断数据集.xlsx')
plt.figure(figsize=(10, 8))
n, bins, patches = plt.hist(df['半径'], bins=100, color='b', alpha=0.5)
plt.xlabel('肿瘤半径', fontsize=20)
plt.ylabel('人数', fontsize=20)
plt.title('肿瘤半径频率分布图')

y = norm.pdf(bins, df['半径'].mean(), df['半径'].std())
ax2 = plt.twinx()
ax2.plot(bins, y, 'k--')
ax2.set_ylabel('概率分布', fontsize=20)
plt.savefig('./img/肿瘤半径频率分布图.png', transparent=False)
plt.show()

# %% [markdown]
# ## 肿瘤半径与紧凑性的关系(散点图)

# %%
df = pd.read_excel('乳腺癌诊断数据集.xlsx')
x = df['半径']
y = df['紧凑性']
plt.scatter(x, y, color='c', marker='p')
plt.legend(labels=['紧凑性'])
plt.title('肿瘤半径与紧凑性的关系', fontsize=40)
plt.xlabel('半径', fontsize=20)
plt.ylabel('紧凑性', fontsize=20)
plt.savefig('./img/肿瘤半径与紧凑性的关系(散点图).png', transparent=False)
plt.show()

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号
df = pd.read_excel('腰痛病数据集.xlsx')
x = df['sacral_slope-骶骨斜坡']
y = df['sacrum_angle-骶骨角']
plt.scatter(x, y, color='r', s=50,marker='D',edgecolors='w')
plt.legend(labels=['骶骨角'])
plt.title('骶骨斜坡与骶骨角的关系', fontsize=40)
plt.xlabel('骶骨斜坡', fontsize=20)
plt.ylabel('骶骨角', fontsize=20)
plt.savefig('骶骨斜坡与骶骨角的关系(散点图).png', transparent=False)
plt.show()

# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号
df = pd.read_excel('腰痛病数据集.xlsx')
df = df.sort_values(by='thoracic_slope-胸斜率')
x = df['thoracic_slope-胸斜率']
y = df['lumbar_lordosis_angle-腰椎病']
plt.plot(x, y, color='b',linewidth=1,linestyle='dotted')
plt.title('胸斜率与腰椎病', fontsize=20)
plt.xlabel('胸斜率', fontsize=10)
plt.ylabel('腰椎病', fontsize=10)
plt.savefig('胸斜率与腰椎病的关系分析图.png', transparent=False)
plt.show()

# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号
df = pd.read_excel('乳腺癌诊断数据集.xlsx')
df = df.sort_values(by='半径')
x = df['半径']
y = df['分形维数']
plt.plot(x, y, color='r')
plt.title('肿瘤半径与分形维数', fontsize=30)
plt.xlabel('半径', fontsize=20)
plt.ylabel('分形维数', fontsize=20)
plt.savefig('乳腺癌肿瘤半径与分形维数的关系分析图.png', transparent=False)
plt.show()

# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号
df = pd.read_excel('腰痛病数据集.xlsx')
x = df['pelvic_radius-骨盆半径']
y = df['pelvic_slope-骨盆斜度']
plt.scatter(x, y, color='c', marker='p')
plt.legend(labels=['骨盆斜度'])
plt.title('骨盆半径与骨盆斜度的关系', fontsize=40)
plt.xlabel('骨盆半径', fontsize=20)
plt.ylabel('骨盆斜度', fontsize=20)
plt.savefig('骨盆半径与骨盆斜度的关系(散点图).png', transparent=False)
plt.show()

# %%
import pandas as pd
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号
df = pd.read_excel('腰痛病数据集.xlsx')
df = df.sort_values(by='pelvic_incidence-骨盆感染')
x = df['pelvic_incidence-骨盆感染']
y = df['lumbar_lordosis_angle-腰椎病']
plt.plot(x, y, color='r',linewidth=1,linestyle='dashdot')
plt.title('骨盆感染与腰椎病', fontsize=20)
plt.xlabel('骨盆感染', fontsize=10)
plt.ylabel('腰椎病', fontsize=10)
plt.savefig('骨盆感染与腰椎病的关系分析图.png', transparent=False)
plt.show()

# %%
df
# Out:
#      pelvic_incidence-骨盆感染  pelvic_tilt-骨盆倾斜  lumbar_lordosis_angle-腰椎病  \
# 26               26.147921         10.759454                  14.000000
# 53               30.149936         11.917445                  34.000000
# 215              30.741938         13.354966                  35.903526
# 11               31.232387         17.715819                  15.500000
# 17               31.276012          3.144669                  32.562996
# ..                     ...               ...                        ...
# 206              95.480229         46.550053                  59.000000
# 96               96.657315         19.461581                  90.211498
# 163             115.923261         37.515436                  76.800000
# 162             118.144655         38.449501                  50.838520
# 115             129.834041          8.404475                  48.384057
#
#      sacral_slope-骶骨斜坡  pelvic_radius-骨盆半径  degree_spondylolisthesis-腰椎滑脱度  \
# 26           15.388468          125.203296                      -10.093108
# 53           18.232491          112.684141                       11.463223
# 215          17.386972          142.410107                       -2.005373
# 11           13.516568          120.055399                        0.499751
# 17           28.131342          129.011418                        3.623020
# ..                 ...                 ...                             ...
# 206          48.930176           96.683903                       77.283072
# 96           77.195734          120.673041                       64.080998
# 163          78.407825          104.698603                       81.198927
# 162          79.695154           81.024541                       74.043767
# 115         121.429566          107.690466                      418.543082
#
#      pelvic_slope-骨盆斜度  cervical_tilt-颈倾斜  thoracic_slope-胸斜率  \
# 26            0.391971             9.8710              8.6406
# 53            0.659772            12.0969             10.7071
# 215           0.326835            16.5218             18.0205
# 11            0.608343            21.4356              9.2589
# 17            0.534481            31.1641             18.6089
# ..                 ...                ...                 ...
# 206           0.778848            29.8380             14.5939
# 96            0.623388            21.5013             13.0551
# 163           0.542816            22.3317              8.8519
# 162           0.599393            35.8563             10.9266
# 115           0.860223            18.5943             11.1514
#
#      cervical_tilt-颈倾斜.1  sacrum_angle-骶骨角  scoliosis_slope-脊柱侧弯  \
# 26              15.78046        -19.650163               43.9550
# 53              16.18484         -4.763914               26.8917
# 215              7.55792          2.002130               30.1215
# 11              14.76412        -21.724559               36.4449
# 17               8.44020          4.482424               24.6513
# ..                   ...               ...                   ...
# 206             12.22450        -21.695815               38.7849
# 96              11.35399        -14.093301               20.8180
# 163             11.48960         -6.754004               32.5082
# 162             13.11354        -17.520810               21.2408
# 115             11.36543        -34.202073               27.5144
#
#     Class_att-丙氨酸类                   注释：
# 26        Abnormal                   NaN
# 53        Abnormal                   NaN
# 215         Normal                   NaN
# 11        Abnormal  scoliosis_slope-脊柱侧弯
# 17        Abnormal                   NaN
# ..             ...                   ...
# 206       Abnormal                   NaN
# 96        Abnormal                   NaN
# 163       Abnormal                   NaN
# 162       Abnormal                   NaN
# 115       Abnormal                   NaN
#
# [310 rows x 14 columns]

# %%
df_radius =df.groupby(pd.cut(x=df['pelvic_radius-骨盆半径'], bins=np.arange(70, 164, 5))).mean()
plt.scatter(df_radius['pelvic_radius-骨盆半径'], df_radius['lumbar_lordosis_angle-腰椎病'])
plt.xlabel('骨盆半径')
plt.ylabel('腰椎病')
plt.show()
# Out:
# C:\Users\32858\AppData\Local\Temp\ipykernel_8612\1953186917.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_radius =df.groupby(pd.cut(x=df['pelvic_radius-骨盆半径'], bins=np.arange(70, 164, 5))).mean()
