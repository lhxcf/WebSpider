# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 读取经过处理的体质表（已经过去重处理，并计算出相应的体质信息）
df = pd.read_excel(r"C:\Users\32858\Desktop\中医体质问卷分析\中医体质问卷_21信管_第二轮.xlsx")
df
# Out:
#     序号             提交答卷时间  所用时间    来源  来源详情                   来自IP  \
# 0    1   2024/3/5 8:56:37  229秒  手机提交  直接访问  223.104.51.114(福建-福州)
# 1    2   2024/3/5 8:57:41  400秒    微信   NaN  223.104.51.137(福建-莆田)
# 2    3   2024/3/5 8:59:45  449秒  手机提交  直接访问  117.136.75.219(福建-福州)
# 3    4   2024/3/5 8:59:52  321秒    微信   NaN   27.149.108.51(福建-福州)
# 4    5   2024/3/5 9:00:03  475秒    微信   NaN   112.54.35.168(福建-福州)
# 5    6   2024/3/5 9:00:03  358秒  手机提交  直接访问  112.111.55.128(福建-福州)
# 6    7   2024/3/5 9:00:39  537秒  手机提交  直接访问    27.148.28.94(福建-福州)
# 7    8   2024/3/5 9:00:57  306秒  手机提交  直接访问  27.149.115.251(福建-福州)
# 8    9   2024/3/5 9:01:23  476秒  手机提交  直接访问  112.111.55.149(福建-福州)
# 9   10   2024/3/5 9:01:35  478秒    微信   NaN   112.54.35.141(福建-福州)
# 10  11   2024/3/5 9:01:39  525秒    微信   NaN  27.149.113.194(福建-福州)
# 11  12   2024/3/5 9:01:43  493秒  手机提交  直接访问   183.250.24.19(福建-福州)
# 12  13   2024/3/5 9:04:28  527秒    微信   NaN  110.86.214.176(福建-福州)
# 13  14   2024/3/5 9:06:45  430秒    微信   NaN  223.104.51.176(福建-莆田)
# 14  15   2024/3/5 9:07:32  490秒  手机提交  直接访问     112.54.35.4(福建-福州)
# 15  16   2024/3/5 9:07:42  502秒    微信   NaN     112.54.35.7(福建-福州)
# 16  17   2024/3/5 9:07:46  245秒  手机提交  直接访问  120.32.207.134(福建-厦门)
# 17  18   2024/3/5 9:08:33  292秒  手机提交  直接访问   27.149.91.104(福建-福州)
# 18  19   2024/3/5 9:09:41  359秒  手机提交  直接访问   110.86.205.62(福建-福州)
# 19  20  2024/3/5 10:33:25   96秒  手机提交  直接访问   120.32.206.34(福建-厦门)
# 20  21  2024/3/5 10:34:14  148秒  手机提交  直接访问  223.104.51.121(福建-福州)
# 21  22  2024/3/5 10:37:41  373秒    微信   NaN   112.54.35.152(福建-福州)
# 22  23  2024/3/5 10:38:26  392秒  手机提交  直接访问    183.250.24.8(福建-福州)
# 23  24  2024/3/5 10:39:11  447秒  手机提交  直接访问    112.54.35.30(福建-福州)
# 24  25  2024/3/5 10:39:24  369秒  手机提交  直接访问   27.149.28.138(福建-福州)
# 25  26  2024/3/5 10:40:23  529秒    微信   NaN     112.54.35.7(福建-福州)
# 26  27  2024/3/5 10:40:26  267秒  手机提交  直接访问     112.54.35.3(福建-福州)
# 27  28  2024/3/5 10:43:47  284秒  手机提交  直接访问    183.250.24.7(福建-福州)
# 28  29  2024/3/5 10:45:47  220秒    微信   NaN   110.88.105.94(福建-福州)
# 29  30  2024/3/5 16:15:02  178秒  手机提交  直接访问   27.148.88.118(福建-福州)
# 30  31  2024/3/5 16:16:25  280秒  手机提交  直接访问   27.149.58.147(福建-福州)
# 31  32  2024/3/5 16:16:28  211秒  手机提交  直接访问  112.49.233.109(福建-福州)
# 32  33  2024/3/5 16:16:30  180秒  手机提交  直接访问   223.104.51.87(福建-福州)
# 33  34  2024/3/5 16:16:50  315秒  手机提交  直接访问  110.88.104.181(福建-福州)
# 34  35  2024/3/5 16:17:31  285秒  手机提交  直接访问   110.88.103.90(福建-福州)
# 35  36  2024/3/5 16:17:51  127秒  手机提交  直接访问  110.88.104.181(福建-福州)
# 36  37  2024/3/5 16:18:19  303秒  手机提交  直接访问   112.111.55.64(福建-福州)
# 37  38  2024/3/5 16:18:40  113秒  手机提交  直接访问  112.111.55.245(福建-福州)
# 38  39  2024/3/5 16:19:48  186秒  手机提交  直接访问   120.32.152.64(福建-厦门)
# 39  40  2024/3/5 16:19:58  269秒  手机提交  直接访问   36.251.82.108(福建-福州)
# 40  41  2024/3/5 16:20:03  475秒  手机提交  直接访问  112.49.233.109(福建-福州)
# 41  42  2024/3/5 16:20:28  200秒  手机提交  直接访问   27.149.70.243(福建-福州)
# 42  43  2024/3/5 16:20:35  240秒  手机提交  直接访问   36.251.82.108(福建-福州)
# 43  44  2024/3/5 16:20:39  244秒  手机提交  直接访问   27.148.103.48(福建-福州)
# 44  45  2024/3/5 16:23:16  393秒  手机提交  直接访问   112.54.35.127(福建-福州)
# 45  46  2024/3/5 16:26:02  144秒  手机提交  直接访问   36.251.82.108(福建-福州)
# 46  47  2024/3/5 16:34:27  236秒  手机提交  直接访问    110.86.192.2(福建-莆田)
# 47  48  2024/3/5 16:35:57  497秒  手机提交  直接访问  110.88.104.174(福建-福州)
# 48  49  2024/3/5 16:45:22  614秒  手机提交  直接访问  27.148.100.235(福建-福州)
# 49  50  2024/3/5 17:04:54  332秒  手机提交  直接访问   27.149.57.127(福建-福州)
# 50  51  2024/3/5 22:48:22  209秒  手机提交  直接访问   110.88.109.15(福建-福州)
#
#           1、学号 2、姓名  3、年龄  4、性别  ...  特禀质  平和质（是/否）  气虚质（是/否）  阳虚质（是/否）  \
# 0   3210707038   陈俊    22     1  ...   29         否         是       倾向是
# 1   3210707004  廖丽珍    20     2  ...   18         否         是         是
# 2   3210707007  谢晓丹    21     2  ...   46         否         是         是
# 3   3210707052   杨铝    21     1  ...   29         否       倾向是       倾向是
# 4   3210707012  胡羽心    20     2  ...   32         否       倾向是         否
# 5   3210707053   焦航    21     1  ...   25         否         是         否
# 6   3210707031  何端锴    21     1  ...   25         是         否         否
# 7   3210707046  郝怡容    22     2  ...   25       倾向是       倾向是       倾向是
# 8          (空)    慈    21     2  ...   25         否         是         是
# 9   3210707006  罗清香    20     2  ...   36         否       倾向是         是
# 10  3210707030  郑美珠    21     2  ...   39       倾向是         否         否
# 11  3210707029  杜思婷    21     2  ...   32         否         否         否
# 12  3210707050  张怡菲    20     2  ...   18         否       倾向是       倾向是
# 13  3210707014  钟稚琴    22     2  ...   54         否         是         是
# 14  3210707017  张丽瑄    20     2  ...   32         否         是         否
# 15  3210707005  王诗琴    20     2  ...   14         否       倾向是         是
# 16  3210707057  王益民    19     1  ...   18         否         是         是
# 17  3210707028  黄梅娟    21     2  ...   39         否         是         否
# 18  3210707013  李佳佳    20     2  ...   21         否       倾向是         是
# 19  3210707015  官祥杰    21     1  ...   25         否         是         否
# 20  3210707047  张轶文    22     1  ...   11         是         否         否
# 21  3210707001  田杰红    22     2  ...   14       倾向是         否       倾向是
# 22  3210707008  刘浩雄    21     1  ...   11         否         否         是
# 23  3210707002   刘兰    21     2  ...   21         否         是         是
# 24  3210707040   何伟    21     1  ...   11         是         否         否
# 25  3210707049   朱康    22     1  ...   50         否       倾向是         否
# 26  3210707034  陈海林    22     1  ...    0       倾向是         否         否
# 27  3210707021   陈红    21     2  ...   11       倾向是         否         否
# 28  3210707033  郑婉玲    21     2  ...   18         否         否         是
# 29  3210707003  吴争宇    20     1  ...   25         是         否         否
# 30  3210707020  余昕玥    20     2  ...   25         否         是       倾向是
# 31  3210707023  刘远龙    22     1  ...    4         否         否         否
# 32  3210707019  李海智    20     1  ...   21       倾向是         否         否
# 33  3210707011  陈伟平    22     1  ...   18         是         否         否
# 34  3210707055  王耀鹏    21     1  ...   29         否         是         否
# 35  3210707009  程琨耀    22     1  ...   39         否         否         否
# 36  3210707018  蔡世鹏    20     1  ...    0         是         否         否
# 37  3210707043  马海鹏    20     1  ...   50         否         是         是
# 38  3210707056  黎东康    21     1  ...    0         否         是         是
# 39  3210707045  林皓宇    21     1  ...   25         是         否         否
# 40  3210707026  黄建锐    21     1  ...   21         否         否         否
# 41  3120707060  陈剑峰    21     1  ...    7         是         否         否
# 42  3210707042   郑豹    21     1  ...   43         否         是       倾向是
# 43  3210707059  冯子斌    21     1  ...   32       倾向是         否         否
# 44  3210707010  李健铭    22     1  ...   21         是         否         否
# 45  3210707041  蔡洲鹏    18     1  ...   39         否         是         是
# 46  3210707027  王嘉欣    20     2  ...   32         否       倾向是         是
# 47  3210707044  许雪敏    21     2  ...   14         否       倾向是       倾向是
# 48  3210707022  侯晨露    20     2  ...   32         否         是         是
# 49  3210707024  胡远媛    21     2  ...   61         否         是         是
# 50  3210707037  刘晓丹    21     2  ...   32         否         是         是
#
#     阴虚质（是/否）  痰湿质（是/否）  湿热质（是/否）  淤血质（是/否）  气郁质（是/否）  特禀质（是/否）
# 0        倾向是       倾向是       倾向是         否       倾向是         否
# 1          是         否       倾向是         是         是         否
# 2          是       倾向是       倾向是         是         是         是
# 3          是         否         否         否         否         否
# 4          否         是         是       倾向是         是       倾向是
# 5        倾向是         否         否       倾向是         是         否
# 6          否         否         否         否         否         否
# 7          否         否       倾向是       倾向是         否         否
# 8          是       倾向是       倾向是         是       倾向是         否
# 9        倾向是         否       倾向是         是         是       倾向是
# 10         否         否         否       倾向是         否       倾向是
# 11         是         否       倾向是       倾向是       倾向是       倾向是
# 12         是         否         否         是       倾向是         否
# 13       倾向是         否       倾向是         是       倾向是         是
# 14         是         否         否         是         是       倾向是
# 15       倾向是         否         否       倾向是         否         否
# 16         是         是       倾向是         是         是         否
# 17         是         否         否         是         是       倾向是
# 18         是       倾向是         是         是       倾向是         否
# 19         否         否         否         否         否         否
# 20         否         否         否         否         否         否
# 21         否         否       倾向是       倾向是         否         否
# 22         否         否         是         是         否         否
# 23       倾向是       倾向是         否       倾向是       倾向是         否
# 24         否         否         否         否         否         否
# 25       倾向是         否       倾向是       倾向是         否         是
# 26         否         否         否         否       倾向是         否
# 27       倾向是         否       倾向是         否         否         否
# 28         否         否         否         否         否         否
# 29         否         否         否         否         否         否
# 30         是       倾向是         否         是       倾向是         否
# 31         否         否         否         否         否         否
# 32       倾向是         否         否         否         否         否
# 33         否         否         否         否         否         否
# 34         否       倾向是         否         否         否         否
# 35       倾向是       倾向是       倾向是         是         否       倾向是
# 36         否         否         否         否         否         否
# 37         是         是         是         是         是         是
# 38         是         是         否       倾向是         是         否
# 39         否         否         否         否         否         否
# 40         是         是       倾向是       倾向是         是         否
# 41         否         否         否         否         否         否
# 42       倾向是         是         是         否         是         是
# 43         否         否         否       倾向是       倾向是       倾向是
# 44         否         否         否         否         否         否
# 45         是         是         是         是       倾向是       倾向是
# 46       倾向是         否         是       倾向是         否       倾向是
# 47       倾向是         是       倾向是       倾向是         是         否
# 48       倾向是         是       倾向是         是         是       倾向是
# 49         是       倾向是       倾向是         是         是         是
# 50         是       倾向是         是         是         是       倾向是
#
# [51 rows x 91 columns]

# %% [markdown]
# ## 检查数据是否有缺失值，由于有缺失值无法获得正确的体质信息，故直接舍去

# %%
# 截取包含9中体质得分的数据
df1 = df[['平和质', '气虚质', '阳虚质', '阴虚质', '痰湿质', '湿热质', '瘀血质', '气郁质', '特禀质']]

# 检查、处理缺失值
print(f'len_df={len(df)}')
df1 = df1.dropna()
print(f'len_df={len(df)}')
# Out:
# len_df=51
# len_df=51

# %% [markdown]
# ### （1）计算全班9种体质类型的平均分、标准差等基础数据
# #### count:计数（数据条数）
# #### mean:均值
# #### std:标准差
# #### min:最小值
# #### 25%:下四分位数
# #### 50%:中分位数
# #### 75%:上四分位数
# #### max:最大值

# %%
df1.describe()
# Out:
#              平和质        气虚质        阳虚质        阴虚质        痰湿质        湿热质  \
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean   60.843137  34.509804  32.058824  31.666667  24.960784  29.372549
# std    14.300171  16.400454  17.697923  13.530213  14.154802  14.197128
# min    36.000000   6.000000   0.000000   0.000000   0.000000   0.000000
# 25%    50.000000  22.000000  19.500000  23.500000  16.000000  18.000000
# 50%    61.000000  34.000000  32.000000  31.000000  25.000000  29.000000
# 75%    73.000000  47.000000  43.000000  41.000000  36.000000  39.000000
# max    86.000000  69.000000  71.000000  56.000000  50.000000  57.000000
#
#              瘀血质        气郁质        特禀质
# count  51.000000  51.000000  51.000000
# mean   32.333333  31.411765  25.470588
# std    13.693307  14.517819  13.819339
# min     0.000000   0.000000   0.000000
# 25%    25.000000  21.000000  18.000000
# 50%    36.000000  32.000000  25.000000
# 75%    43.000000  43.000000  32.000000
# max    54.000000  71.000000  61.000000

# %% [markdown]
# ### 由上述分析结果可知，相交于第一次体质调查的数据，没有了“平和质转化分”中最大值为100，远超上四分位数及其均值的数据，从上述分析来看，数据质量较高
# ### 各体质方差分布于[13.530213，17.697923],分布相对集中

# %% [markdown]
# ### （2）计算全班不同性别同学9种体质类型的平均分、标准差；
# #### 按性别分组，后计算题均值、方差
# #### 1:男
# #### 2:女

# %%
# df1表添加一列性别信息，用于分组统计
df1['性别'] = df['4、性别']

# 分组统计
group = df1.groupby(df1['性别'])
print('均值如下：')
print(f'{group.mean()}')
print('方差如下：')
print(f'{group.std()}')
# Out:
# 均值如下：
#           平和质        气虚质        阳虚质        阴虚质        痰湿质        湿热质  \
# 性别
# 1   64.962963  28.888889  23.777778  26.740741  23.148148  25.444444
# 2   56.208333  40.833333  41.375000  37.208333  27.000000  33.791667
#
#           瘀血质        气郁质        特禀质
# 性别
# 1   25.740741  26.333333  22.518519
# 2   39.750000  37.125000  28.791667
# 方差如下：
#           平和质        气虚质        阳虚质        阴虚质        痰湿质        湿热质  \
# 性别
# 1   14.410150  16.293777  15.064817  14.789790  16.190462  15.400633
# 2   12.941269  14.345630  15.915026   9.495899  11.447422  11.470109
#
#           瘀血质        气郁质        特禀质
# 性别
# 1   13.971379  14.371446  14.238005
# 2    8.862476  12.663925  12.816359

# %% [markdown]
# ### (3)全班9种体质类型（是、倾向是、否）的频数分布；
# #### 先从df表中提取有用列，再统计频率

# %%
# 提取相关的体质信息df2
df2 = df[['平和质（是/否）','气虚质（是/否）','阳虚质（是/否）', '阴虚质（是/否）', '痰湿质（是/否）', '湿热质（是/否）', '淤血质（是/否）', '气郁质（是/否）', '特禀质（是/否）']]

# 检查、处理缺失值
print(f'len_df={len(df)}')
df2 = df2.dropna()
print(f'len_df={len(df)}')
# Out:
# len_df=51
# len_df=51

# %% [markdown]
# ### 数据中的“否”等信息可能末尾或首部有空格，导致分组时分为多组，故下面要处理首位的空格

# %%
for col in df2.columns:
    df2[col] = df2[col].str.strip()
df2
# Out:
#    平和质（是/否） 气虚质（是/否） 阳虚质（是/否） 阴虚质（是/否） 痰湿质（是/否） 湿热质（是/否） 淤血质（是/否） 气郁质（是/否）  \
# 0         否        是      倾向是      倾向是      倾向是      倾向是        否      倾向是
# 1         否        是        是        是        否      倾向是        是        是
# 2         否        是        是        是      倾向是      倾向是        是        是
# 3         否      倾向是      倾向是        是        否        否        否        否
# 4         否      倾向是        否        否        是        是      倾向是        是
# 5         否        是        否      倾向是        否        否      倾向是        是
# 6         是        否        否        否        否        否        否        否
# 7       倾向是      倾向是      倾向是        否        否      倾向是      倾向是        否
# 8         否        是        是        是      倾向是      倾向是        是      倾向是
# 9         否      倾向是        是      倾向是        否      倾向是        是        是
# 10      倾向是        否        否        否        否        否      倾向是        否
# 11        否        否        否        是        否      倾向是      倾向是      倾向是
# 12        否      倾向是      倾向是        是        否        否        是      倾向是
# 13        否        是        是      倾向是        否      倾向是        是      倾向是
# 14        否        是        否        是        否        否        是        是
# 15        否      倾向是        是      倾向是        否        否      倾向是        否
# 16        否        是        是        是        是      倾向是        是        是
# 17        否        是        否        是        否        否        是        是
# 18        否      倾向是        是        是      倾向是        是        是      倾向是
# 19        否        是        否        否        否        否        否        否
# 20        是        否        否        否        否        否        否        否
# 21      倾向是        否      倾向是        否        否      倾向是      倾向是        否
# 22        否        否        是        否        否        是        是        否
# 23        否        是        是      倾向是      倾向是        否      倾向是      倾向是
# 24        是        否        否        否        否        否        否        否
# 25        否      倾向是        否      倾向是        否      倾向是      倾向是        否
# 26      倾向是        否        否        否        否        否        否      倾向是
# 27      倾向是        否        否      倾向是        否      倾向是        否        否
# 28        否        否        是        否        否        否        否        否
# 29        是        否        否        否        否        否        否        否
# 30        否        是      倾向是        是      倾向是        否        是      倾向是
# 31        否        否        否        否        否        否        否        否
# 32      倾向是        否        否      倾向是        否        否        否        否
# 33        是        否        否        否        否        否        否        否
# 34        否        是        否        否      倾向是        否        否        否
# 35        否        否        否      倾向是      倾向是      倾向是        是        否
# 36        是        否        否        否        否        否        否        否
# 37        否        是        是        是        是        是        是        是
# 38        否        是        是        是        是        否      倾向是        是
# 39        是        否        否        否        否        否        否        否
# 40        否        否        否        是        是      倾向是      倾向是        是
# 41        是        否        否        否        否        否        否        否
# 42        否        是      倾向是      倾向是        是        是        否        是
# 43      倾向是        否        否        否        否        否      倾向是      倾向是
# 44        是        否        否        否        否        否        否        否
# 45        否        是        是        是        是        是        是      倾向是
# 46        否      倾向是        是      倾向是        否        是      倾向是        否
# 47        否      倾向是      倾向是      倾向是        是      倾向是      倾向是        是
# 48        否        是        是      倾向是        是      倾向是        是        是
# 49        否        是        是        是      倾向是      倾向是        是        是
# 50        否        是        是        是      倾向是        是        是        是
#
#    特禀质（是/否）
# 0         否
# 1         否
# 2         是
# 3         否
# 4       倾向是
# 5         否
# 6         否
# 7         否
# 8         否
# 9       倾向是
# 10      倾向是
# 11      倾向是
# 12        否
# 13        是
# 14      倾向是
# 15        否
# 16        否
# 17      倾向是
# 18        否
# 19        否
# 20        否
# 21        否
# 22        否
# 23        否
# 24        否
# 25        是
# 26        否
# 27        否
# 28        否
# 29        否
# 30        否
# 31        否
# 32        否
# 33        否
# 34        否
# 35      倾向是
# 36        否
# 37        是
# 38        否
# 39        否
# 40        否
# 41        否
# 42        是
# 43      倾向是
# 44        否
# 45      倾向是
# 46      倾向是
# 47        否
# 48      倾向是
# 49        是
# 50      倾向是

# %% [markdown]
# ### 再次进行计数统计

# %%
for col in df2.columns:
    value_counts = df2[col].value_counts()
    print(f'{col} 的频数统计如下：\n{value_counts}')
# Out:
# 平和质（是/否） 的频数统计如下：
# 平和质（是/否）
# 否      35
# 是       9
# 倾向是     7
# Name: count, dtype: int64
# 气虚质（是/否） 的频数统计如下：
# 气虚质（是/否）
# 否      21
# 是      20
# 倾向是    10
# Name: count, dtype: int64
# 阳虚质（是/否） 的频数统计如下：
# 阳虚质（是/否）
# 否      25
# 是      18
# 倾向是     8
# Name: count, dtype: int64
# 阴虚质（是/否） 的频数统计如下：
# 阴虚质（是/否）
# 否      20
# 是      17
# 倾向是    14
# Name: count, dtype: int64
# 痰湿质（是/否） 的频数统计如下：
# 痰湿质（是/否）
# 否      32
# 倾向是    10
# 是       9
# Name: count, dtype: int64
# 湿热质（是/否） 的频数统计如下：
# 湿热质（是/否）
# 否      26
# 倾向是    17
# 是       8
# Name: count, dtype: int64
# 淤血质（是/否） 的频数统计如下：
# 淤血质（是/否）
# 否      19
# 是      18
# 倾向是    14
# Name: count, dtype: int64
# 气郁质（是/否） 的频数统计如下：
# 气郁质（是/否）
# 否      24
# 是      16
# 倾向是    11
# Name: count, dtype: int64
# 特禀质（是/否） 的频数统计如下：
# 特禀质（是/否）
# 否      33
# 倾向是    12
# 是       6
# Name: count, dtype: int64

# %% [markdown]
# ### （4）全班不同性别同学9种体质类型（是、倾向是、否）的频数分布；

# %%
# df2表添加一列性别信息，用于分组统计
df2['性别'] = df['4、性别']

# 分组统计
for col in df2.columns:
    group = df2[col].groupby(df2['性别'])
    print(group.value_counts())
# Out:
# 性别  平和质（是/否）
# 1   否           15
#     是            9
#     倾向是          3
# 2   否           20
#     倾向是          4
# Name: count, dtype: int64
# 性别  气虚质（是/否）
# 1   否           16
#     是            9
#     倾向是          2
# 2   是           11
#     倾向是          8
#     否            5
# Name: count, dtype: int64
# 性别  阳虚质（是/否）
# 1   否           19
#     是            5
#     倾向是          3
# 2   是           13
#     否            6
#     倾向是          5
# Name: count, dtype: int64
# 性别  阴虚质（是/否）
# 1   否           15
#     倾向是          6
#     是            6
# 2   是           11
#     倾向是          8
#     否            5
# Name: count, dtype: int64
# 性别  痰湿质（是/否）
# 1   否           18
#     是            6
#     倾向是          3
# 2   否           14
#     倾向是          7
#     是            3
# Name: count, dtype: int64
# 性别  湿热质（是/否）
# 1   否           18
#     倾向是          5
#     是            4
# 2   倾向是         12
#     否            8
#     是            4
# Name: count, dtype: int64
# 性别  淤血质（是/否）
# 1   否           17
#     倾向是          5
#     是            5
# 2   是           13
#     倾向是          9
#     否            2
# Name: count, dtype: int64
# 性别  气郁质（是/否）
# 1   否           17
#     是            6
#     倾向是          4
# 2   是           10
#     倾向是          7
#     否            7
# Name: count, dtype: int64
# 性别  特禀质（是/否）
# 1   否           21
#     倾向是          3
#     是            3
# 2   否           12
#     倾向是          9
#     是            3
# Name: count, dtype: int64
# 性别  性别
# 1   1     27
# 2   2     24
# Name: count, dtype: int64

# %% [markdown]
# ### （5）统计所有体质类型判定为“是”的情况，每位同学有可能有多个体质类型判定为“是”，需要增加一列“兼杂体质数”，统计全班兼杂体质的频数分布。
# #### 首先统计所有体质判定为”是“的计数，并新增“兼杂体质数”列，统计分布

# %%
count = 0
# 遍历值，判断是否为“是”
for col in df2.columns:
    num = (df2[col] == '是').sum()
    count += num
print(f'所有体质中判定为“是”的个数：{count}')
# Out:
# 所有体质中判定为“是”的个数：121

# %% [markdown]
# ### 添加一列“兼杂体质数”

# %%
# 使用apply()函数和lambda表达式计算每行中值为“是”的个数
df2['兼杂体质数'] = df.apply(lambda row: row.eq('是').sum(), axis=1)
count_j = (df2['兼杂体质数'] > 1).sum()
print(f'参与统计的同学中，兼杂体质的同学占比：{count_j/len(df2)}')
# Out:
# 参与统计的同学中，兼杂体质的同学占比：0.49019607843137253

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号

# %% [markdown]
# ### 绘制关于我班“兼杂体质数”的饼图

# %%
# 定义数据和标签
labels = ['兼杂体质', '非兼杂体质']
is_jz = count_j/len(df2)
sizes = [is_jz, 1-is_jz] # 这些数字代表每个部分在整体中的比例或数量

# 创建饼图
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

ax1.axis('equal')

plt.show()

# %% [markdown]
# ### 对比上次的统计数据来看，本学期数据质量较高，能更好的反应同学的体质状况，数据可信度高，有约一半的同学为兼杂体制，符合客观认知。
