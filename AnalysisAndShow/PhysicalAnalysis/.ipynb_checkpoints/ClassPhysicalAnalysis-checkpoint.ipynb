# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 读取经过处理的体质表（已经过去重处理，并计算出相应的体质信息）
df = pd.read_excel(r"C:\Users\32858\Desktop\中医体质问卷分析\中医体质问卷_21信管_第一轮 .xlsx")
df
# Out:
#     序号              提交答卷时间  所用时间    来源  来源详情                   来自IP  \
# 0    1   2023/2/24 9:54:17  150秒  手机提交  直接访问   27.148.73.178(福建-福州)
# 1    2   2023/2/24 9:55:18  212秒  手机提交  直接访问  110.86.195.198(福建-厦门)
# 2    3   2023/2/24 9:55:24  107秒  手机提交  直接访问   223.104.51.20(福建-福州)
# 3    4   2023/2/24 9:55:58  133秒  手机提交  直接访问   112.54.35.127(福建-福州)
# 4    5   2023/2/24 9:56:03  266秒  手机提交  直接访问    183.250.24.7(福建-福州)
# 5    6   2023/2/24 9:56:07  255秒  手机提交  直接访问    112.111.6.46(福建-福州)
# 6    7   2023/2/24 9:56:07  257秒  手机提交  直接访问   112.111.55.35(福建-福州)
# 7    8   2023/2/24 9:56:15  206秒  手机提交  直接访问   223.104.51.54(福建-福州)
# 8    9   2023/2/24 9:56:17  262秒  手机提交  直接访问  140.243.221.87(福建-福州)
# 9   10   2023/2/24 9:56:20  284秒  手机提交  直接访问   58.22.113.157(福建-福州)
# 10  11   2023/2/24 9:56:22  287秒  手机提交  直接访问    27.149.76.79(福建-福州)
# 11  12   2023/2/24 9:56:24  288秒  手机提交  直接访问   27.149.95.159(福建-福州)
# 12  13   2023/2/24 9:56:30  290秒  手机提交  直接访问    112.111.55.6(福建-福州)
# 13  14   2023/2/24 9:56:43  287秒  手机提交  直接访问   223.104.51.21(福建-福州)
# 14  15   2023/2/24 9:56:45  292秒  手机提交  直接访问    27.149.55.48(福建-福州)
# 15  16   2023/2/24 9:56:54  314秒  手机提交  直接访问    183.250.24.4(福建-福州)
# 16  17   2023/2/24 9:56:58  319秒  手机提交  直接访问  117.136.75.185(福建-福州)
# 17  18   2023/2/24 9:57:06  271秒  手机提交  直接访问   112.54.35.168(福建-福州)
# 18  19   2023/2/24 9:57:18  268秒  手机提交  直接访问   183.250.24.19(福建-福州)
# 19  20   2023/2/24 9:57:22  276秒  手机提交  直接访问   223.104.51.46(福建-福州)
# 20  21   2023/2/24 9:57:24  347秒  手机提交  直接访问   112.54.35.127(福建-福州)
# 21  22   2023/2/24 9:57:26  266秒  手机提交  直接访问   27.148.92.223(福建-福州)
# 22  23   2023/2/24 9:57:29  286秒  手机提交  直接访问  112.111.55.159(福建-福州)
# 23  24   2023/2/24 9:57:30  346秒  手机提交  直接访问     112.54.35.7(福建-福州)
# 24  25   2023/2/24 9:57:32  339秒  手机提交  直接访问    27.149.68.55(福建-福州)
# 25  26   2023/2/24 9:57:45  348秒  手机提交  直接访问    223.104.47.4(福建-福州)
# 26  27   2023/2/24 9:57:47  366秒  手机提交  直接访问   27.148.117.34(福建-福州)
# 27  28   2023/2/24 9:57:48  331秒  手机提交  直接访问    27.148.63.42(福建-福州)
# 28  29   2023/2/24 9:57:53  249秒  手机提交  直接访问   223.104.51.50(福建-福州)
# 29  30   2023/2/24 9:57:57  293秒  手机提交  直接访问     27.148.57.2(福建-福州)
# 30  31   2023/2/24 9:58:00  376秒  手机提交  直接访问     112.54.35.4(福建-福州)
# 31  33   2023/2/24 9:58:08  136秒  手机提交  直接访问  112.111.55.249(福建-福州)
# 32  34   2023/2/24 9:58:09  371秒  手机提交  直接访问   117.136.75.53(福建-福州)
# 33  35   2023/2/24 9:58:14  335秒  手机提交  直接访问   27.148.107.85(福建-福州)
# 34  36   2023/2/24 9:58:34  402秒  手机提交  直接访问   183.250.24.19(福建-福州)
# 35  37   2023/2/24 9:58:34  397秒  手机提交  直接访问    112.54.35.30(福建-福州)
# 36  38   2023/2/24 9:58:45  349秒  手机提交  直接访问   112.54.35.127(福建-福州)
# 37  39   2023/2/24 9:58:54  432秒  手机提交  直接访问   183.250.24.19(福建-福州)
# 38  40   2023/2/24 9:59:00  190秒  手机提交  直接访问  117.136.75.161(福建-福州)
# 39  41   2023/2/24 9:59:02  405秒  手机提交  直接访问    183.250.24.4(福建-福州)
# 40  42   2023/2/24 9:59:18  428秒  手机提交  直接访问   223.104.51.10(福建-福州)
# 41  43  2023/2/24 10:00:16  443秒  手机提交  直接访问   27.149.84.234(福建-福州)
# 42  44  2023/2/24 10:00:21  211秒  手机提交  直接访问   27.149.95.159(福建-福州)
# 43  45  2023/2/24 10:00:38  265秒  手机提交  直接访问   112.54.35.127(福建-福州)
# 44  46  2023/2/24 10:10:22  695秒  手机提交  直接访问     112.54.35.7(福建-福州)
# 45  47  2023/2/24 10:15:00  362秒  手机提交  直接访问   183.250.24.18(福建-福州)
#
#           1、学号 2、姓名  3、年龄  4、性别  ...  特禀质转化分  平和质（是/否）  气虚质（是/否）  阳虚质（是/否）  \
# 0   3210707043  马海鹏    19     1  ...      11         否         是       倾向是
# 1   3210707028  黄梅娟    19     2  ...      43         否         是       倾向是
# 2   3210707041  蔡洲鹏    18     1  ...      50         否         是         是
# 3   3210707008  刘浩雄    20     1  ...       0         否         否         否
# 4   3210707021   陈红    20     2  ...      11         否         否         否
# 5   3210707033  郑婉玲    19     2  ...      14         是         否         否
# 6   3210707025  赖朔玉    20     2  ...      46         否         是         是
# 7   3210707019  李海智    18     1  ...      46         否       倾向是       倾向是
# 8   3210707002   刘兰    20     2  ...       4       倾向是       倾向是         否
# 9   3210707026  黄建锐    20     1  ...      14         否         是         是
# 10  3210707051   俞琪    19     2  ...      11         否         否       倾向是
# 11  3210707027  王嘉欣    19     2  ...      36         否       倾向是         是
# 12  3210707053   焦航    20     1  ...      25         否       倾向是         否
# 13  3210707017  张丽瑄    19     2  ...      14         否         是       倾向是
# 14  3210707040   何伟    19     1  ...       7         否         否         否
# 15  3210707030  郑美珠    19     2  ...      25       倾向是         否       倾向是
# 16  3210707016  吴煜城    20     1  ...      11       倾向是       倾向是         否
# 17  3210707010  李健铭    20     1  ...      29       倾向是         否         否
# 18  3210707046  郝怡容    21     2  ...      21         否         是         是
# 19  3210707056  黎东康    20     1  ...      21         否         是         是
# 20  3210707052   杨铝    20     1  ...      39       倾向是       倾向是       倾向是
# 21  3210707055  王耀鹏    20     1  ...      14         否         是         否
# 22  3210707057  王益民    18     1  ...      29         否         是         是
# 23  3210707013  李佳佳    19     2  ...      36         否       倾向是         是
# 24  3210707059  冯子斌    20     1  ...      14         是         否         否
# 25  3210707007  谢晓丹    20     2  ...      43         否         是         是
# 26  3210707034  陈海林    21     1  ...      14       倾向是         否         否
# 27  3210707020  余昕玥    19     2  ...      21         否         是       倾向是
# 28  3210707047  张轶文    21     1  ...       4       倾向是         否         否
# 29  3210707022  侯晨露    20     2  ...      46         否         是         是
# 30  3210707004  廖丽珍    20     2  ...      21       倾向是         否         否
# 31  3210707018  蔡世鹏    19     1  ...      25         是         否         否
# 32  3210707014  钟稚琴    21     2  ...      32         否       倾向是       倾向是
# 33  3210707060  陈剑峰    20     1  ...      14         是         否         否
# 34  3210707006  罗清香    19     2  ...      29         否       倾向是         否
# 35  3210707012  胡羽心    19     2  ...      46         否       倾向是         否
# 36  3210707015  官祥杰    20     1  ...      29         否       倾向是         否
# 37   321707029  杜思婷    19     2  ...      29       倾向是         否         否
# 38  3210707023  刘远龙    20     1  ...       7         否         否         否
# 39  3210707001  田杰红    21     2  ...       7       倾向是         否         否
# 40  3210707005  王诗琴    19     2  ...       0         是         否         否
# 41  3210707031  何端锴    20     1  ...      36       倾向是       倾向是         否
# 42  3210707024  胡远媛    20     2  ...      43         否         是         是
# 43  3210707049   朱康    20     1  ...      39       倾向是         否         否
# 44  3210707044  许雪敏    19     2  ...       7         否       倾向是         是
# 45  3210707038   陈俊    20     1  ...      25         否         是         否
#
#     阴虚质（是/否）  痰湿质（是/否）  湿热质（是/否）  淤血质（是/否）  气郁质（是/否）  特禀质（是/否）
# 0          是         否         否         否         是         否
# 1          否       倾向是       倾向是       倾向是       倾向是         是
# 2          否       倾向是       倾向是         是         是         是
# 3          是         否         否         否         否         否
# 4          是         否         否         否         否         否
# 5          否         否         否         否         否         否
# 6          否         是         否         是         是         是
# 7          是       倾向是         否         否       倾向是         是
# 8        倾向是         否         否         否         否         否
# 9          否         是       倾向是         否       倾向是         否
# 10         是         否         否         是         否         否
# 11         否         否         是         是       倾向是       倾向是
# 12         是         否         否         否       倾向是         否
# 13         否         否       倾向是         是         是         否
# 14         是         否         否         否         否         否
# 15         否         否         否       倾向是       倾向是         否
# 16         否         否       倾向是         否         否         否
# 17         否         否         否       倾向是         否         否
# 18         否       倾向是         是         是         是         否
# 19         否         是       倾向是         否         是         否
# 20         否         否       倾向是         否         否       倾向是
# 21       倾向是         否       倾向是         否       倾向是         否
# 22         是         否         是       倾向是         否         否
# 23         否         否         是         是         否       倾向是
# 24         否         否         否         否         否         否
# 25         否       倾向是       倾向是       倾向是       倾向是         是
# 26       倾向是         否         否         否         否         否
# 27         是         否         是       倾向是         是         否
# 28         否         否         否       倾向是         否         否
# 29       倾向是       倾向是         是         是         是         是
# 30       倾向是         否         否         否         否         否
# 31         否         否         否         否         否         否
# 32         否         否         是         是       倾向是       倾向是
# 33         否         否         否         否         否         否
# 34         否         否         否         是       倾向是         否
# 35         否         是       倾向是       倾向是       倾向是         是
# 36       倾向是       倾向是       倾向是         是       倾向是         否
# 37       倾向是         否       倾向是       倾向是         否         否
# 38         否         否         否         否         否         否
# 39         否         否       倾向是       倾向是         否         否
# 40         否         否         否         否         否         否
# 41       倾向是         否         否         否       倾向是       倾向是
# 42       倾向是         否         否         否       倾向是         是
# 43         否         否         否         否         否       倾向是
# 44       倾向是         是       倾向是         否         是         否
# 45         否         否       倾向是         否         否         否
#
# [46 rows x 91 columns]

# %% [markdown]
# ## 检查数据是否有缺失值，由于有缺失值无法获得正确的体质信息，故直接舍去

# %%
# 截取包含9中体质得分的数据
df1 = df[['平和质转化分', '气虚质转化分', '阳虚质转化分', '阴虚质转化分', '痰湿质转化分', '湿热质转化分', '瘀血质转化分', '气郁质转化分', '特禀质转化分']]

# 检查、处理缺失值
print(f'len_df={len(df)}')
df1 = df1.dropna()
print(f'len_df={len(df)}')
# Out:
# len_df=46
# len_df=46

# %% [markdown]
# ### （1）计算全班9种体质类型的平均分、标准差等基础数据
# #### count:计数（数据条数）
# #### mean:均值
# #### std:标准差
# #### min:最小值
# #### 25%:下四分位数
# #### 50%:中分位数
# #### 75%:上四分位数
# #### max:最大值

# %%
df1.describe()
# Out:
#            平和质转化分     气虚质转化分     阳虚质转化分     阴虚质转化分     痰湿质转化分     湿热质转化分  \
# count   46.000000  46.000000  46.000000  46.000000  46.000000  46.000000
# mean    62.326087  33.608696  30.413043  28.826087  21.826087  27.717391
# std     12.649206  14.306919  16.450027  10.688112  12.863910  13.644149
# min     32.000000   0.000000   0.000000   3.000000   0.000000   0.000000
# 25%     54.750000  22.750000  21.000000  22.000000  12.000000  18.000000
# 50%     61.000000  32.500000  29.000000  28.000000  22.000000  29.000000
# 75%     68.000000  44.000000  42.000000  38.000000  30.250000  36.000000
# max    100.000000  72.000000  71.000000  50.000000  50.000000  61.000000
#
#           瘀血质转化分     气郁质转化分     特禀质转化分
# count  46.000000  46.000000  46.000000
# mean   29.086957  28.804348  23.652174
# std    14.517156  13.945321  14.363870
# min     0.000000   0.000000   0.000000
# 25%    18.750000  18.000000  11.750000
# 50%    29.000000  30.500000  23.000000
# 75%    39.000000  39.000000  36.000000
# max    71.000000  54.000000  50.000000

# %% [markdown]
# ### 由上述分析结果可知，“平和质转化分”中最大值为100，远超上四分位数及其均值，判断为填写时被调查者未认真填写，故在研究总体体质分布时，应舍去该值所在的那条信息；
# ### 各体质方差分布于[10.688112，16.450027],分布相对集中

# %% [markdown]
# ### （2）计算全班不同性别同学9种体质类型的平均分、标准差；
# #### 按性别分组，后计算题均值、方差
# #### 1:男
# #### 2:女

# %%
# df1表添加一列性别信息，用于分组统计
df1['性别'] = df['4、性别']

# 分组统计
group = df1.groupby(df1['性别'])
print('均值如下：')
print(f'{group.mean()}')
print('方差如下：')
print(f'{group.std()}')
# Out:
# 均值如下：
#        平和质转化分     气虚质转化分     阳虚质转化分     阴虚质转化分     痰湿质转化分     湿热质转化分  \
# 性别
# 1   65.478261  31.565217  23.565217  30.521739  20.869565  23.695652
# 2   59.173913  35.652174  37.260870  27.130435  22.782609  31.739130
#
#        瘀血质转化分     气郁质转化分     特禀质转化分
# 性别
# 1   21.608696  25.347826  21.869565
# 2   36.565217  32.260870  25.434783
# 方差如下：
#        平和质转化分     气虚质转化分     阳虚质转化分     阴虚质转化分     痰湿质转化分     湿热质转化分  \
# 性别
# 1   13.300272  13.006383  14.390104  10.582445  12.839231  12.433221
# 2   11.384408  15.517171  15.760184  10.754721  13.104324  13.870234
#
#        瘀血质转化分     气郁质转化分     特禀质转化分
# 性别
# 1   11.987642  15.537663  13.699052
# 2   13.055219  11.462260  15.090111

# %% [markdown]
# ### (3)全班9种体质类型（是、倾向是、否）的频数分布；
# #### 先从df表中提取有用列，再统计频率

# %%
# 提取相关的体质信息df2
df2 = df[['平和质（是/否）','气虚质（是/否）','阳虚质（是/否）', '阴虚质（是/否）', '痰湿质（是/否）', '湿热质（是/否）', '淤血质（是/否）', '气郁质（是/否）', '特禀质（是/否）']]

# 检查、处理缺失值
print(f'len_df={len(df)}')
df2 = df2.dropna()
print(f'len_df={len(df)}')
# Out:
# len_df=46
# len_df=46

# %% [markdown]
# ### 数据中的“否”等信息可能末尾或首部有空格，导致分组时分为多组，故下面要处理首位的空格

# %%
for col in df2.columns:
    df2[col] = df2[col].str.strip()
df2
# Out:
#    平和质（是/否） 气虚质（是/否） 阳虚质（是/否） 阴虚质（是/否） 痰湿质（是/否） 湿热质（是/否） 淤血质（是/否） 气郁质（是/否）  \
# 0         否        是      倾向是        是        否        否        否        是
# 1         否        是      倾向是        否      倾向是      倾向是      倾向是      倾向是
# 2         否        是        是        否      倾向是      倾向是        是        是
# 3         否        否        否        是        否        否        否        否
# 4         否        否        否        是        否        否        否        否
# 5         是        否        否        否        否        否        否        否
# 6         否        是        是        否        是        否        是        是
# 7         否      倾向是      倾向是        是      倾向是        否        否      倾向是
# 8       倾向是      倾向是        否      倾向是        否        否        否        否
# 9         否        是        是        否        是      倾向是        否      倾向是
# 10        否        否      倾向是        是        否        否        是        否
# 11        否      倾向是        是        否        否        是        是      倾向是
# 12        否      倾向是        否        是        否        否        否      倾向是
# 13        否        是      倾向是        否        否      倾向是        是        是
# 14        否        否        否        是        否        否        否        否
# 15      倾向是        否      倾向是        否        否        否      倾向是      倾向是
# 16      倾向是      倾向是        否        否        否      倾向是        否        否
# 17      倾向是        否        否        否        否        否      倾向是        否
# 18        否        是        是        否      倾向是        是        是        是
# 19        否        是        是        否        是      倾向是        否        是
# 20      倾向是      倾向是      倾向是        否        否      倾向是        否        否
# 21        否        是        否      倾向是        否      倾向是        否      倾向是
# 22        否        是        是        是        否        是      倾向是        否
# 23        否      倾向是        是        否        否        是        是        否
# 24        是        否        否        否        否        否        否        否
# 25        否        是        是        否      倾向是      倾向是      倾向是      倾向是
# 26      倾向是        否        否      倾向是        否        否        否        否
# 27        否        是      倾向是        是        否        是      倾向是        是
# 28      倾向是        否        否        否        否        否      倾向是        否
# 29        否        是        是      倾向是      倾向是        是        是        是
# 30      倾向是        否        否      倾向是        否        否        否        否
# 31        是        否        否        否        否        否        否        否
# 32        否      倾向是      倾向是        否        否        是        是      倾向是
# 33        是        否        否        否        否        否        否        否
# 34        否      倾向是        否        否        否        否        是      倾向是
# 35        否      倾向是        否        否        是      倾向是      倾向是      倾向是
# 36        否      倾向是        否      倾向是      倾向是      倾向是        是      倾向是
# 37      倾向是        否        否      倾向是        否      倾向是      倾向是        否
# 38        否        否        否        否        否        否        否        否
# 39      倾向是        否        否        否        否      倾向是      倾向是        否
# 40        是        否        否        否        否        否        否        否
# 41      倾向是      倾向是        否      倾向是        否        否        否      倾向是
# 42        否        是        是      倾向是        否        否        否      倾向是
# 43      倾向是        否        否        否        否        否        否        否
# 44        否      倾向是        是      倾向是        是      倾向是        否        是
# 45        否        是        否        否        否      倾向是        否        否
#
#    特禀质（是/否）
# 0         否
# 1         是
# 2         是
# 3         否
# 4         否
# 5         否
# 6         是
# 7         是
# 8         否
# 9         否
# 10        否
# 11      倾向是
# 12        否
# 13        否
# 14        否
# 15        否
# 16        否
# 17        否
# 18        否
# 19        否
# 20      倾向是
# 21        否
# 22        否
# 23      倾向是
# 24        否
# 25        是
# 26        否
# 27        否
# 28        否
# 29        是
# 30        否
# 31        否
# 32      倾向是
# 33        否
# 34        否
# 35        是
# 36        否
# 37        否
# 38        否
# 39        否
# 40        否
# 41      倾向是
# 42        是
# 43      倾向是
# 44        否
# 45        否

# %%
### 再次进行计数统计

# %%
for col in df2.columns:
    value_counts = df2[col].value_counts()
    print(f'{col} 的频数统计如下：\n{value_counts}')
# Out:
# 平和质（是/否） 的频数统计如下：
# 平和质（是/否）
# 否      29
# 倾向是    12
# 是       5
# Name: count, dtype: int64
# 气虚质（是/否） 的频数统计如下：
# 气虚质（是/否）
# 否      18
# 是      15
# 倾向是    13
# Name: count, dtype: int64
# 阳虚质（是/否） 的频数统计如下：
# 阳虚质（是/否）
# 否      25
# 是      12
# 倾向是     9
# Name: count, dtype: int64
# 阴虚质（是/否） 的频数统计如下：
# 阴虚质（是/否）
# 否      27
# 倾向是    10
# 是       9
# Name: count, dtype: int64
# 痰湿质（是/否） 的频数统计如下：
# 痰湿质（是/否）
# 否      34
# 倾向是     7
# 是       5
# Name: count, dtype: int64
# 湿热质（是/否） 的频数统计如下：
# 湿热质（是/否）
# 否      24
# 倾向是    15
# 是       7
# Name: count, dtype: int64
# 淤血质（是/否） 的频数统计如下：
# 淤血质（是/否）
# 否      25
# 是      11
# 倾向是    10
# Name: count, dtype: int64
# 气郁质（是/否） 的频数统计如下：
# 气郁质（是/否）
# 否      23
# 倾向是    14
# 是       9
# Name: count, dtype: int64
# 特禀质（是/否） 的频数统计如下：
# 特禀质（是/否）
# 否      32
# 是       8
# 倾向是     6
# Name: count, dtype: int64

# %% [markdown]
# ### （4）全班不同性别同学9种体质类型（是、倾向是、否）的频数分布；

# %%
# df2表添加一列性别信息，用于分组统计
df2['性别'] = df['4、性别']

# 分组统计
for col in df2.columns:
    group = df2[col].groupby(df2['性别'])
    print(group.value_counts())
# Out:
# 性别  平和质（是/否）
# 1   否           13
#     倾向是          7
#     是            3
# 2   否           16
#     倾向是          5
#     是            2
# Name: count, dtype: int64
# 性别  气虚质（是/否）
# 1   否           10
#     是            7
#     倾向是          6
# 2   否            8
#     是            8
#     倾向是          7
# Name: count, dtype: int64
# 性别  阳虚质（是/否）
# 1   否           16
#     是            4
#     倾向是          3
# 2   否            9
#     是            8
#     倾向是          6
# Name: count, dtype: int64
# 性别  阴虚质（是/否）
# 1   否           13
#     是            6
#     倾向是          4
# 2   否           14
#     倾向是          6
#     是            3
# Name: count, dtype: int64
# 性别  痰湿质（是/否）
# 1   否           18
#     倾向是          3
#     是            2
# 2   否           16
#     倾向是          4
#     是            3
# Name: count, dtype: int64
# 性别  湿热质（是/否）
# 1   否           14
#     倾向是          8
#     是            1
# 2   否           10
#     倾向是          7
#     是            6
# Name: count, dtype: int64
# 性别  淤血质（是/否）
# 1   否           18
#     倾向是          3
#     是            2
# 2   是            9
#     倾向是          7
#     否            7
# Name: count, dtype: int64
# 性别  气郁质（是/否）
# 1   否           14
#     倾向是          6
#     是            3
# 2   否            9
#     倾向是          8
#     是            6
# Name: count, dtype: int64
# 性别  特禀质（是/否）
# 1   否           18
#     倾向是          3
#     是            2
# 2   否           14
#     是            6
#     倾向是          3
# Name: count, dtype: int64
# 性别  性别
# 1   1     23
# 2   2     23
# Name: count, dtype: int64

# %% [markdown]
# ### （5）统计所有体质类型判定为“是”的情况，每位同学有可能有多个体质类型判定为“是”，需要增加一列“兼杂体质数”，统计全班兼杂体质的频数分布。
# #### 首先统计所有体质判定为”是“的计数，并新增“兼杂体质数”列，统计分布

# %%
count = 0
# 遍历值，判断是否为“是”
for col in df2.columns:
    num = (df2[col] == '是').sum()
    count += num
print(f'所有体质中判定为“是”的个数：{count}')
# Out:
# 所有体质中判定为“是”的个数：81

# %% [markdown]
# ### 添加一列“兼杂体质数”

# %%
# 使用apply()函数和lambda表达式计算每行中值为“是”的个数
df2['兼杂体质数'] = df.apply(lambda row: row.eq('是').sum(), axis=1)
count_j = (df2['兼杂体质数'] > 1).sum()
print(f'参与统计的同学中，兼杂体质的同学占比：{count_j/len(df2)}')
# Out:
# 参与统计的同学中，兼杂体质的同学占比：0.43478260869565216

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']    # 设置可显示中文，不出现乱码,字体为黑体
plt.rcParams['axes.unicode_minus'] = False  # 设置可显示负号

# %% [markdown]
# ### 绘制关于我班“兼杂体质数”的饼图

# %%
# 定义数据和标签
labels = ['兼杂体质', '非兼杂体质']
is_jz = count_j/len(df2)
sizes = [is_jz, 1-is_jz] # 这些数字代表每个部分在整体中的比例或数量

# 创建饼图
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

ax1.axis('equal')

plt.show()
